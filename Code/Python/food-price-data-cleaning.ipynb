# %% [markdown]
# The food price data is obtained from [Humanitarian Data Exchange](https://data.humdata.org/dataset/?dataseries_name=WFP+-+Food+Prices).

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta

# %%
country = 'Nigeria'

# %%
topfolder = '/Users/sahoko/GitHub/Food-insecurity-GP-forecasting/'
datafolder = os.path.join(topfolder,'Data/New/FoodPrice')
os.chdir(topfolder)

# %%
file = f"{datafolder}/Raw/{country}/wfp_food_prices.csv"
df = pd.read_csv(file, header=0, skiprows=[1])

# %%
df.loc[df['category']=='cereals and tubers']['unit'].unique()
# Out:
# array(['KG', '100 KG', '50 KG', 'Unit', '1.3 KG', '1.4 KG', '3.4 KG',
#        '3.1 KG', '100 Tubers', '2.5 KG'], dtype=object)

# %%
df['Datetime'] = pd.to_datetime(df['date'])

# %% [markdown]
# Data cleaning
# * Same as Fioni 2023
#     1. Limit the data to cereal and tuber category [2018>]
#     2. price (in USD) -> adjust for the unit
#     3. Interpolate if missing
#     4. Subset the data with 'commodity' that are available to all the adminstrative regions of the same country
#     5. Normalise each subcategory time series
#     6. Take the mean over all sub-categories
#     7. limit time series from starting month - end month {at the end}
# * Some question
#     1. pricetype / priceflag should they be all treated the same? or only using a certain pricetype or price flag
#         check `df_ct['priceflag'].unique()` or `df_ct['pricetype'].unique()`
#     2. USD or adjusted currency (adjusted for income in USD or so)
#
# * Modified [1]
#     1. 1-3 the same as above
#     2. interpolate (daily or weekly...)
# * Modified [2]
#     1. 1-3 the same as above
#     2. PCA on time series?

# %% [markdown]
# 1. Limit the data to cereal and tuber category

# %%
df_ct = df.loc[(df['category']=='cereals and tubers') & (df['Datetime']>pd.to_datetime('2018-01-01'))].copy()

# %% [markdown]
# 2. price (in USD) -> adjust for the unit
#     By running `df_ct['unit'].unique()` we get
#     ```
#     ['KG', '100 KG', '50 KG', 'Unit', '1.3 KG', '1.4 KG', '3.4 KG',
#        '3.1 KG', '100 Tubers', '2.5 KG']
#     ```
#     ---------
#    * We see that `'100 Tubers'` are used for Yam or Yam (Abuja), and `'Unit'` is used for Bread. Check `df_ct.loc[df_ct['unit']=='Unit']['commodity'].unique()` for example.
#
#    * We remove the data entreies where the price is measured with `100 Tubers` but keep the one with `Unit`, i.e., bread
#
#    * Note `Yam (Abuja)` is only recorded for the admin1 region  `'Oyo'`
#    ---------
#    * To adjust for unit, split the numerical part and the unit e.g. `'2.5'` and  `'KG'` in `'2.5 KG'` and take the former to create a nuw column `'unit_numeric'`
#    * If for each date-time, admin1 region and commodity, thre are multiple entries, take the mean

# %%
df_ct = df_ct.loc[df_ct['unit']!='100 Tubers'].copy()

# %%
df_ct['unit'].replace('KG', '1 KG', inplace=True)
df_ct['unit_numeric'] = 1.0
df_ct.loc[df_ct['unit']!='Unit',['unit_numeric']] = df_ct.loc[df_ct['unit']!='Unit']['unit'].str[:-3].astype(float)

# %%
df_ct['usdprice_unit'] = df_ct['usdprice']/df_ct['unit_numeric']
df_ct['price_unit'] = df_ct['price']/df_ct['unit_numeric']

# %%
df_ct_unique = df_ct.groupby(['Datetime', 'admin1','commodity']).agg({'usdprice_unit':'mean', 'price_unit':'mean'}).reset_index()

# %%
df_ct_unique_temp  =  df_ct_unique.drop('price_unit', axis=1)
df_ct_unique_temp = df_ct_unique_temp.set_index(['Datetime','admin1','commodity']).unstack('commodity').reset_index()
df_ct_unique_temp.columns  = ['_'.join(col) for col in df_ct_unique_temp.columns]
df_ct_unique_temp.rename(columns={'Datetime_':'Datetime','admin1_':'admin1'}, inplace=True)

# %% [markdown]
# 3. Interpolate if missing
#     3.1 Make dataframe with Datetime (all) X admin 1

# %% [markdown]
# ### Need to be updated from here ###

# %%
region_list = list(df_ct_unique['admin1'].unique())
region_number = len(region_list)
date = list(pd.date_range(df_ct_unique['Datetime'].min() - timedelta(days=30), df_ct_unique['Datetime'].max(),freq='MS') + pd.DateOffset(days=14))
date_length = len(date)
d = {'Datetime':date*region_number,
     'admin1':np.repeat(region_list, date_length)}
df1 = pd.DataFrame(data=d)
df1 = df1.sort_values(by=['admin1','Datetime'])

# %%
df2  =  df_ct_unique.drop('price_unit', axis=1)
df2 = df2.set_index(['Datetime','admin1','commodity']).unstack('commodity').reset_index()
df2.columns  = ['_'.join(col) for col in df2.columns]
df2.rename(columns={'Datetime_':'Datetime','admin1_':'admin1'}, inplace=True)

# %%
df_merge = pd.merge(df1,df2,how="outer",on=['Datetime','admin1'])

# %%
d = {'Datetime':date}
df1 = pd.DataFrame(data=d)

# %%
df2  =  df_ct_unique.drop('price_unit', axis=1)
df2 = df2.set_index(['Datetime','admin1','commodity']).unstack(['admin1','commodity']).reset_index()
#df2.rename(columns={'Datetime_':'Datetime','admin1_':'admin1'}, inplace=True)

# %%
df2.columns  = ['_'.join(col) for col in df2.columns]
df2.rename(columns={'Datetime__':'Datetime'}, inplace=True)

# %%
df_merge = pd.merge(df1,df2,how="outer",on=['Datetime'])

# %%
df_merge
# Out:
#      Datetime  usdprice_unit_Borno_Bread  \
# 0  2018-01-15                    0.98325
# 1  2018-02-15                    1.00775
# 2  2018-03-15                    1.09580
# 3  2018-04-15                    1.26890
# 4  2018-05-15                    1.11150
# ..        ...                        ...
# 67 2023-08-15                        NaN
# 68 2023-09-15                        NaN
# 69 2023-10-15                        NaN
# 70 2023-11-15                        NaN
# 71 2023-12-15                        NaN
#
#     usdprice_unit_Borno_Cassava meal (gari, yellow)  \
# 0                                          0.890050
# 1                                          0.431428
# 2                                          0.366702
# 3                                          0.451755
# 4                                          0.432778
# ..                                              ...
# 67                                              NaN
# 68                                              NaN
# 69                                              NaN
# 70                                              NaN
# 71                                              NaN
#
#     usdprice_unit_Borno_Gari (white)  usdprice_unit_Borno_Maize (white)  \
# 0                           0.646649                           0.254408
# 1                           0.371372                           0.233333
# 2                           0.324174                           0.261905
# 3                           0.376773                                NaN
# 4                           0.353806                           0.283889
# ..                               ...                                ...
# 67                               NaN                                NaN
# 68                               NaN                                NaN
# 69                               NaN                                NaN
# 70                               NaN                                NaN
# 71                               NaN                                NaN
#
#     usdprice_unit_Borno_Maize (yellow)  usdprice_unit_Borno_Maize flour  \
# 0                             0.283050                         0.421942
# 1                             0.280112                         0.579077
# 2                             0.284734                         0.781077
# 3                             0.341866                         0.460154
# 4                             0.308278                         0.419725
# ..                                 ...                              ...
# 67                                 NaN                         0.608227
# 68                                 NaN                         0.626188
# 69                                 NaN                         0.618551
# 70                                 NaN                         0.524154
# 71                                 NaN                         0.745295
#
#     usdprice_unit_Borno_Millet  usdprice_unit_Borno_Rice (imported)  \
# 0                     0.419927                             1.097878
# 1                     0.459466                             1.075919
# 2                     0.462038                             1.130120
# 3                     0.468748                             1.280603
# 4                     0.350880                             1.049570
# ..                         ...                                  ...
# 67                    0.658443                             1.468749
# 68                    0.643425                             1.504878
# 69                    0.627842                             1.566798
# 70                    0.591335                             1.475406
# 71                    0.618511                             1.682880
#
#     usdprice_unit_Borno_Rice (local)  ...  usdprice_unit_Abia_Maize (white)  \
# 0                           0.727052  ...                               NaN
# 1                           0.809817  ...                               NaN
# 2                           0.765250  ...                               NaN
# 3                           0.897134  ...                               NaN
# 4                           0.822029  ...                               NaN
# ..                               ...  ...                               ...
# 67                          1.120905  ...                               NaN
# 68                          1.206729  ...                               NaN
# 69                          1.227171  ...                               NaN
# 70                          1.123489  ...                               NaN
# 71                          1.193477  ...                               NaN
#
#     usdprice_unit_Abia_Maize (yellow)  usdprice_unit_Abia_Millet  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ..                                ...                        ...
# 67                                NaN                        NaN
# 68                                NaN                        NaN
# 69                                NaN                        NaN
# 70                                NaN                        NaN
# 71                                NaN                        NaN
#
#     usdprice_unit_Abia_Rice (imported)  usdprice_unit_Abia_Rice (local)  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ..                                 ...                              ...
# 67                                 NaN                              NaN
# 68                                 NaN                              NaN
# 69                                 NaN                              NaN
# 70                                 NaN                              NaN
# 71                                 NaN                              NaN
#
#     usdprice_unit_Abia_Sorghum (brown)  usdprice_unit_Abia_Sorghum (white)  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ..                                 ...                                 ...
# 67                                 NaN                                 NaN
# 68                                 NaN                                 NaN
# 69                                 NaN                                 NaN
# 70                                 NaN                                 NaN
# 71                                 NaN                                 NaN
#
#     usdprice_unit_Abia_Yam  usdprice_unit_Adamawa_Maize flour  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
# ..                     ...                                ...
# 67                     NaN                            0.58224
# 68                     NaN                            0.71430
# 69                     NaN                            0.65626
# 70                     NaN                            0.60220
# 71                     NaN                            0.63110
#
#     usdprice_unit_Adamawa_Sorghum
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 67                        0.67556
# 68                        0.64924
# 69                        0.66464
# 70                        0.62756
# 71                        0.54190
#
# [72 rows x 157 columns]

# %%
def interpolation(x): 
    # Let's interpolate the NaN values using a linear interpolation up to a limit of 3 months.
    x = x.loc[x.first_valid_index():x.last_valid_index()]
    x = x.interpolate(method = "linear", limit = 3)
    # Keep only the commodities that not have any nan values.
    return x.dropna(axis = 1, how = "any")

# %%
a = df_merge.loc[df_merge['admin1']=='Zamfara'].set_index(['Datetime','admin1'])
a = a.loc[a.first_valid_index(): a.last_valid_index()]

# %%
a = df_merge.set_index('Datetime')
a.loc[a.first_valid_index(): a.last_valid_index()].interpolate(method = "linear", limit = 3).dropna(axis = 1, how = "any")
# Out:
#             usdprice_unit_Borno_Millet  usdprice_unit_Borno_Rice (imported)  \
# Datetime
# 2018-01-15                    0.419927                             1.097878
# 2018-02-15                    0.459466                             1.075919
# 2018-03-15                    0.462038                             1.130120
# 2018-04-15                    0.468748                             1.280603
# 2018-05-15                    0.350880                             1.049570
# ...                                ...                                  ...
# 2023-08-15                    0.658443                             1.468749
# 2023-09-15                    0.643425                             1.504878
# 2023-10-15                    0.627842                             1.566798
# 2023-11-15                    0.591335                             1.475406
# 2023-12-15                    0.618511                             1.682880
#
#             usdprice_unit_Borno_Rice (local)  usdprice_unit_Borno_Yam  \
# Datetime
# 2018-01-15                          0.727052                 0.442345
# 2018-02-15                          0.809817                 0.440106
# 2018-03-15                          0.765250                 0.408580
# 2018-04-15                          0.897134                 0.615029
# 2018-05-15                          0.822029                 0.857875
# ...                                      ...                      ...
# 2023-08-15                          1.120905                 0.815731
# 2023-09-15                          1.206729                 0.842358
# 2023-10-15                          1.227171                 0.867813
# 2023-11-15                          1.123489                 0.736837
# 2023-12-15                          1.193477                 0.863860
#
#             usdprice_unit_Yobe_Millet  usdprice_unit_Yobe_Rice (imported)  \
# Datetime
# 2018-01-15                   0.523955                            1.842621
# 2018-02-15                   0.532442                            1.932743
# 2018-03-15                   0.522423                            1.884223
# 2018-04-15                   0.606532                            2.129812
# 2018-05-15                   0.498376                            1.661325
# ...                               ...                                 ...
# 2023-08-15                   0.629613                            1.141640
# 2023-09-15                   0.474027                            1.352528
# 2023-10-15                   0.472260                            1.424435
# 2023-11-15                   0.456747                            1.400840
# 2023-12-15                   0.493390                            1.687180
#
#             usdprice_unit_Yobe_Rice (local)  usdprice_unit_Yobe_Yam
# Datetime
# 2018-01-15                         1.217199                0.360935
# 2018-02-15                         1.315930                0.336388
# 2018-03-15                         1.227058                0.308316
# 2018-04-15                         1.492699                0.368155
# 2018-05-15                         1.286703                0.309569
# ...                                     ...                     ...
# 2023-08-15                         1.072580                0.763870
# 2023-09-15                         1.134647                0.816336
# 2023-10-15                         1.036995                0.880314
# 2023-11-15                         0.956360                0.784080
# 2023-12-15                         1.003033                0.849316
#
# [72 rows x 8 columns]

# %%
a.last_valid_index()
# Out:
# (Timestamp('2023-12-15 00:00:00'), 'Zamfara')

# %%
df_merge.loc[df_merge['admin1']=='Zamfara',['usdprice_unit_Bread']]
# Out:
#       usdprice_unit_Bread
# 3432                  NaN
# 3433                  NaN
# 3434                  NaN
# 3435                  NaN
# 3436                  NaN
# ...                   ...
# 3691                  NaN
# 3692                  NaN
# 3693                  NaN
# 3694                  NaN
# 3695                  NaN
#
# [264 rows x 1 columns]

# %%
df_interpolate = df_merge.apply(interpolation)
df_interpolate.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 df_interpolate = df_merge.apply(interpolation)
#       2 df_interpolate.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[203], line 4, in interpolation(x)
#       1 def interpolation(x):
#       2     # Let's interpolate the NaN values using a linear interpolation up to a limit of 3 months.
#       3     x = x.loc[x.first_valid_index():x.last_valid_index()]
# ----> 4     x = x.interpolate(method = "linear", limit = 3)
#       5     # Keep only the commodities that not have any nan values.
#       6     return x.dropna(axis = 1, how = "any")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6063, in Series.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6051 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#    6052 def interpolate(
#    6053     self: Series,
#    (...)
#    6061     **kwargs,
#    6062 ) -> Series | None:
# -> 6063     return super().interpolate(
#    6064         method,
#    6065         axis,
#    6066         limit,
#    6067         inplace,
#    6068         limit_direction,
#    6069         limit_area,
#    6070         downcast,
#    6071         **kwargs,
#    6072     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:7568, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7562 if isna(index).any():
#    7563     raise NotImplementedError(
#    7564         "Interpolation with NaNs in the index "
#    7565         "has not been implemented. Try filling "
#    7566         "those NaNs before interpolating."
#    7567     )
# -> 7568 new_data = obj._mgr.interpolate(
#    7569     method=method,
#    7570     axis=axis,
#    7571     index=index,
#    7572     limit=limit,
#    7573     limit_direction=limit_direction,
#    7574     limit_area=limit_area,
#    7575     inplace=inplace,
#    7576     downcast=downcast,
#    7577     **kwargs,
#    7578 )
#    7580 result = self._constructor(new_data)
#    7581 if should_transpose:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:422, in BaseBlockManager.interpolate(self, **kwargs)
#     421 def interpolate(self: T, **kwargs) -> T:
# --> 422     return self.apply("interpolate", **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:1619, in EABackedBlock.interpolate(self, method, axis, inplace, limit, fill_value, **kwargs)
#    1617     new_values = values.T.fillna(value=fill_value, method=method, limit=limit).T
#    1618 else:
# -> 1619     new_values = values.fillna(value=fill_value, method=method, limit=limit)
#    1620 return self.make_block_same_class(new_values)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/_mixins.py:317, in NDArrayBackedExtensionArray.fillna(self, value, method, limit)
#     313 @doc(ExtensionArray.fillna)
#     314 def fillna(
#     315     self: NDArrayBackedExtensionArrayT, value=None, method=None, limit=None
#     316 ) -> NDArrayBackedExtensionArrayT:
# --> 317     value, method = validate_fillna_kwargs(
#     318         value, method, validate_scalar_dict_value=False
#     319     )
#     321     mask = self.isna()
#     322     # error: Argument 2 to "check_value_size" has incompatible type
#     323     # "ExtensionArray"; expected "ndarray"
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_validators.py:390, in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     388     raise ValueError("Must specify a fill 'value' or 'method'.")
#     389 elif value is None and method is not None:
# --> 390     method = clean_fill_method(method)
#     392 elif value is not None and method is None:
#     393     if validate_scalar_dict_value and isinstance(value, (list, tuple)):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/missing.py:125, in clean_fill_method(method, allow_nearest)
#     123     expecting = "pad (ffill), backfill (bfill) or nearest"
#     124 if method not in valid_methods:
# --> 125     raise ValueError(f"Invalid fill method. Expecting {expecting}. Got {method}")
#     126 return method
#
# ValueError: Invalid fill method. Expecting pad (ffill) or backfill (bfill). Got linear

# %%
df_tmp = df_ct.set_index(['Datetime','admin1','commodity'])

# %%
st_year = '2022'
st_month = '10'
df.loc[df['Datetime']>pd.to_datetime(f"{st_year}-{st_month}-15")]['date'].unique()

# %%
df.loc[df['Datetime']>pd.to_datetime(f"{st_year}-{st_month}-15")]['date'].unique()
# Out:
# array(['2022-02-15', '2022-03-15', '2022-04-15', '2022-05-15',
#        '2023-02-15', '2023-03-15', '2023-04-15', '2023-05-15',
#        '2023-06-15', '2022-06-15', '2022-07-15', '2022-08-15',
#        '2022-09-15', '2022-10-15', '2022-11-15', '2022-12-15',
#        '2023-01-15', '2023-07-15', '2023-08-15', '2023-09-15',
#        '2023-10-15', '2023-11-15', '2023-12-15'], dtype=object)
